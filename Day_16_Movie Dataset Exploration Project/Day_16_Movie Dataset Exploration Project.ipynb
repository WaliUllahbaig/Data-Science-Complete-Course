# %% [markdown]
# # Movie Dataset Exploration Project

# %% [markdown]
# Shah Wali Ullah Baig

# %% [markdown]
# Exploring a fascinating movie dataset 🍿📈! Leveraging Python's Pandas and NumPy, we analyzed viewers' ages, gender, and movie preferences. 🎥👤 From loading data to conducting thorough exploratory data analysis (EDA), we unveiled insights. 💡🔍 Special focus: How many males dared to watch "Barbie"? 🕵️‍♂️🚺 Dive into data-driven movie trends, discovering patterns that make the cinematic experience more intriguing. 🤓🎬

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("movie.csv")
df.head()
# Out:
#    age  is_male        movie
# 0   35    False       Barbie
# 1   42     True  Oppenheimer
# 2   55    False       Barbie
# 3   77     True  Oppenheimer
# 4   31    False       Barbie

# %%
# Display basic information about the dataset
print("Dataset Info:")
print(df.info())

# Display summary statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300000 entries, 0 to 1299999
# Data columns (total 3 columns):
#  #   Column   Non-Null Count    Dtype
# ---  ------   --------------    -----
#  0   age      1300000 non-null  int64
#  1   is_male  1300000 non-null  bool
#  2   movie    1300000 non-null  object
# dtypes: bool(1), int64(1), object(1)
# memory usage: 21.1+ MB
# None
#
# Summary Statistics:
#                 age
# count  1.300000e+06
# mean   4.998845e+01
# std    1.876022e+01
# min    1.800000e+01
# 25%    3.400000e+01
# 50%    5.000000e+01
# 75%    6.600000e+01
# max    8.200000e+01

# %%
# Count males who watched Barbie
male_barbie_count = df[(df['is_male'] == True) & (df['movie'] == 'Barbie')].shape[0]

print(f"The number of males who watched the Barbie movie is: {male_barbie_count}")
# Out:
# The number of males who watched the Barbie movie is: 296065

# %%
# Insight 1: Average Age by Gender
avg_age_by_gender = df.groupby('is_male')['age'].mean()
print("Average Age by Gender:")
print(avg_age_by_gender)
# Out:
# Average Age by Gender:
# is_male
# False    50.009456
# True     49.967440
# Name: age, dtype: float64

# %%
# Insight 2: Most Watched Movie
most_watched_movie = df['movie'].value_counts().idxmax()
print("\nMost Watched Movie:")
print(most_watched_movie)
# Out:
# Most Watched Movie:
# Barbie

# %%
# Insight 3: Gender Distribution
gender_distribution = df['is_male'].value_counts(normalize=True) * 100
print("\nGender Distribution:")
print(gender_distribution)
# Out:
# Gender Distribution:
# False    50.003
# True     49.997
# Name: is_male, dtype: float64

# %%
# Insight 4: Age Distribution by Movie
plt.figure(figsize=(10, 6))
sns.boxplot(x='movie', y='age', data=df, palette='pastel')
plt.title('Age Distribution by Movie')
plt.xlabel('Movie')
plt.ylabel('Age')
plt.show()

# %%
# Insight 5: Movie Preference by Gender
movie_preference_by_gender = df.groupby(['is_male', 'movie']).size().unstack()
print("\nMovie Preference by Gender:")
print(movie_preference_by_gender)
# Out:
# Movie Preference by Gender:
# movie    Barbie  Oppenheimer
# is_male
# False    393298       256741
# True     296065       353896

# %%
# Insight 6: Correlation Matrix
correlation_matrix = df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Shah Wali\AppData\Local\Temp\ipykernel_7596\2250570749.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %%
# Visualize the distribution of 'age'
plt.figure(figsize=(10, 6))
sns.histplot(df['age'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Countplot for movie genres
plt.figure(figsize=(8, 5))
sns.countplot(x='movie', data=df, hue='is_male', palette='viridis')
plt.title('Count of Movies by Gender')
plt.xlabel('Movie')
plt.ylabel('Count')
plt.show()

# %%
# Pairplot to explore relationships
sns.pairplot(df, hue='movie', palette='husl')
plt.suptitle('Pairplot of Age, Gender, and Movie')
plt.show()
